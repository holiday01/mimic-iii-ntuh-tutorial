# %% [markdown]
# ## 1. 資料內容
# ## 2. 視覺化圖表，以類別分區
# ## 3. 視覺化呈現資料以時間排列
# ## 4. 取出病患死亡時間

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

# %%
conn = psycopg2.connect(database="mimic", user="twmimicviewer", 
                        password="twmimicviewer@1234", host="203.145.218.182", port="5432")

## 連接上資料庫，抓取資料。

## 允許python執行postgresql語法
with conn.cursor() as cur:

    ## 觀察查詢筆數
    print(cur.rowcount)
    
    ## SQL語法
    sql = """
    SELECT * FROM sepsis.angus_cohort
    """
    
    ## 執行sql語法
    cur.execute(sql)
    
    ## 取得欄位名稱
    name = [desc[0] for desc in cur.description]
    
    ## fetchall是將所有收尋的資料都寫入 rows 中
    # rows = pd.DataFrame(cur.fetchall())
    angus_cohort = pd.DataFrame(cur.fetchall(),columns=name)
# Out:
# -1

# %%
print(angus_cohort.shape)
angus_cohort.head()
# Out:
# (16048, 15)
#    subject_id  hadm_id  icustay_id      los                   intime  \
# 0       21274   164354      298201   9.8318  2185-09-04 21:48:19.000
# 1       21277   127461      204941   3.8644  2141-09-10 23:14:32.000
# 2       18936   166430      256303   1.3024  2157-01-06 10:36:14.000
# 3       18936   166430      222141   1.0441  2157-01-12 16:59:09.000
# 4       18936   166430      266076  13.8661  2157-01-19 18:53:02.000
#
#                    outtime first_careunit                admittime  \
# 0  2185-09-14 17:46:08.000           MICU  2185-09-01 03:19:00.000
# 1  2141-09-14 19:59:19.000           MICU  2141-09-10 23:13:00.000
# 2  2157-01-07 17:51:42.000            CCU  2157-01-06 10:35:00.000
# 3  2157-01-13 18:02:43.000            CCU  2157-01-06 10:35:00.000
# 4  2157-02-02 15:40:15.000           MICU  2157-01-06 10:35:00.000
#
#                  deathtime                dischtime                      dob  \
# 0  2185-09-14 15:30:00.000  2185-09-14 15:30:00.000  2127-12-23 00:00:00.000
# 1                     None  2141-10-05 15:15:00.000  2063-12-13 00:00:00.000
# 2                     None  2157-02-08 15:30:00.000  2099-11-05 00:00:00.000
# 3                     None  2157-02-08 15:30:00.000  2099-11-05 00:00:00.000
# 4                     None  2157-02-08 15:30:00.000  2099-11-05 00:00:00.000
#
#                        dod gender  age  mortality_90d
# 0  2185-09-14 00:00:00.000      M   58              1
# 1  2141-12-11 00:00:00.000      F   78              0
# 2  2157-10-18 00:00:00.000      M   58              0
# 3  2157-10-18 00:00:00.000      M   58              0
# 4  2157-10-18 00:00:00.000      M   58              0

# %%
len(pd.unique(angus_cohort.icustay_id))
# Out:
# 16048

# %% [markdown]
# ## 操作：把其他的檔案都寫入這裡面，並且觀察檔案
# ### Python環境變數名稱 : 資料表在資料庫的名稱
# 1. GCS : gcs_24
# 2. LAB : lab_24
# 3. SAPSII : sapsii
# 4. UO : uo_24
# 5. Vital : vital_24

# %%
## 允許python執行postgresql語法
with conn.cursor() as cur:

    sql = """
    SELECT * FROM sepsis.gcs_24
    """
    cur.execute(sql)
    name = [desc[0] for desc in cur.description]
    GCS = pd.DataFrame(cur.fetchall(),columns=name)
    
    print(cur.rowcount)
    
    sql = """
    SELECT * FROM sepsis.lab_24
    """
    cur.execute(sql)
    name = [desc[0] for desc in cur.description]
    LAB = pd.DataFrame(cur.fetchall(),columns=name)
    
    print(cur.rowcount)
    
    sql = """
    SELECT * FROM sepsis.sapsii
    """
    cur.execute(sql)
    name = [desc[0] for desc in cur.description]
    SAPSII = pd.DataFrame(cur.fetchall(),columns=name)
    
    print(cur.rowcount)
    
    sql = """
    SELECT * FROM sepsis.uo_24
    """
    cur.execute(sql)
    name = [desc[0] for desc in cur.description]
    UO = pd.DataFrame(cur.fetchall(),columns=name)
    
    print(cur.rowcount)
    
    sql = """
    SELECT * FROM sepsis.vital_24
    """
    cur.execute(sql)
    name = [desc[0] for desc in cur.description]
    Vital = pd.DataFrame(cur.fetchall(),columns=name)
    
    print(cur.rowcount)
# Out:
# 61532
# 61532
# 61532
# 53359
# 59247

# %%
## 將六張表統整成一張，以icustay_id為標準
## pd.merge(x,y,on="colname")

All = pd.merge(angus_cohort,GCS,on="icustay_id")
All = pd.merge(All,LAB,on="icustay_id")
All = pd.merge(All,SAPSII,on="icustay_id")
All = pd.merge(All,UO,on="icustay_id")
All = pd.merge(All,Vital,on="icustay_id")

# %%
All.head()
# Out:
#    subject_id_x  hadm_id_x  icustay_id      los                   intime  \
# 0         21274     164354      298201   9.8318  2185-09-04 21:48:19.000
# 1         21277     127461      204941   3.8644  2141-09-10 23:14:32.000
# 2         18936     166430      256303   1.3024  2157-01-06 10:36:14.000
# 3         18936     166430      222141   1.0441  2157-01-12 16:59:09.000
# 4         18936     166430      266076  13.8661  2157-01-19 18:53:02.000
#
#                    outtime first_careunit                admittime  \
# 0  2185-09-14 17:46:08.000           MICU  2185-09-01 03:19:00.000
# 1  2141-09-14 19:59:19.000           MICU  2141-09-10 23:13:00.000
# 2  2157-01-07 17:51:42.000            CCU  2157-01-06 10:35:00.000
# 3  2157-01-13 18:02:43.000            CCU  2157-01-06 10:35:00.000
# 4  2157-02-02 15:40:15.000           MICU  2157-01-06 10:35:00.000
#
#                  deathtime                dischtime  ... resprate_mean  \
# 0  2185-09-14 15:30:00.000  2185-09-14 15:30:00.000  ...     17.718750
# 1                     None  2141-10-05 15:15:00.000  ...     18.033333
# 2                     None  2157-02-08 15:30:00.000  ...     18.000000
# 3                     None  2157-02-08 15:30:00.000  ...     21.400000
# 4                     None  2157-02-08 15:30:00.000  ...     30.156627
#
#    tempc_min  tempc_max  tempc_mean  spo2_min  spo2_max  spo2_mean  \
# 0  37.222222  38.333333   37.563492      97.0     100.0  99.384615
# 1  36.111111  38.166665   37.063492      98.0     100.0  99.807692
# 2  36.111111  36.833335   36.564815      94.0     100.0  98.909091
# 3  36.222221  37.111113   36.666667      90.0     100.0  98.260870
# 4  36.000002  37.277777   36.736112      62.0     100.0  97.486486
#
#    glucose_min_y  glucose_max_y  glucose_mean
# 0           87.0          103.0     92.333333
# 1           74.0          108.0     88.200000
# 2           97.0          135.0    115.000000
# 3           87.0          205.0    129.250000
# 4           59.0          123.0     79.500000
#
# [5 rows x 110 columns]

# %%
print(All.shape)
len(pd.unique(angus_cohort.gender))
# Out:
# (14811, 110)
# 2

# %%
## print 顯示結果
## str 轉換成字串
## len 顯示長度
## unique 統整存在列表中數據，重複的只會顯示一次
## round(數值,小數點後幾位)

print('Number of ICU stays: ' + str(len(All.icustay_id.unique())))
print('Number of Mortality: ' + str(len(All.mortality_90d[All['mortality_90d']==1])))
print('Number of non-Mortality: ' + str(len(All.mortality_90d[All['mortality_90d']==0])))
print('Percentage of Mortality: ' + str(round(100*len(All.mortality_90d[All['mortality_90d']==1]) / len(All.mortality_90d),0)) + '%')
# Out:
# Number of ICU stays: 14811
# Number of Mortality: 4693
# Number of non-Mortality: 10118
# Percentage of Mortality: 32.0%

# %%
## pd.colunms 顯示欄位
All.columns
list(All.columns)
# Out:
# ['subject_id_x',
#  'hadm_id_x',
#  'icustay_id',
#  'los',
#  'intime',
#  'outtime',
#  'first_careunit',
#  'admittime',
#  'deathtime',
#  'dischtime',
#  'dob',
#  'dod',
#  'gender',
#  'age',
#  'mortality_90d',
#  'subject_id_y',
#  'hadm_id_y',
#  'mingcs',
#  'gcsmotor',
#  'gcsverbal',
#  'gcseyes',
#  'endotrachflag',
#  'subject_id_x',
#  'hadm_id_x',
#  'aniongap_min',
#  'aniongap_max',
#  'albumin_min',
#  'albumin_max',
#  'bands_min',
#  'bands_max',
#  'bicarbonate_min',
#  'bicarbonate_max',
#  'bilirubin_min',
#  'bilirubin_max',
#  'creatinine_min',
#  'creatinine_max',
#  'chloride_min',
#  'chloride_max',
#  'glucose_min_x',
#  'glucose_max_x',
#  'hematocrit_min',
#  'hematocrit_max',
#  'hemoglobin_min',
#  'hemoglobin_max',
#  'lactate_min',
#  'lactate_max',
#  'platelet_min',
#  'platelet_max',
#  'potassium_min',
#  'potassium_max',
#  'ptt_min',
#  'ptt_max',
#  'inr_min',
#  'inr_max',
#  'pt_min',
#  'pt_max',
#  'sodium_min',
#  'sodium_max',
#  'bun_min',
#  'bun_max',
#  'wbc_min',
#  'wbc_max',
#  'subject_id_y',
#  'hadm_id_y',
#  'sapsii',
#  'sapsii_prob',
#  'age_score',
#  'hr_score',
#  'sysbp_score',
#  'temp_score',
#  'pao2fio2_score',
#  'uo_score',
#  'bun_score',
#  'wbc_score',
#  'potassium_score',
#  'sodium_score',
#  'bicarbonate_score',
#  'bilirubin_score',
#  'gcs_score',
#  'comorbidity_score',
#  'admissiontype_score',
#  'subject_id_x',
#  'hadm_id_x',
#  'urineoutput',
#  'subject_id_y',
#  'hadm_id_y',
#  'heartrate_min',
#  'heartrate_max',
#  'heartrate_mean',
#  'sysbp_min',
#  'sysbp_max',
#  'sysbp_mean',
#  'diasbp_min',
#  'diasbp_max',
#  'diasbp_mean',
#  'meanbp_min',
#  'meanbp_max',
#  'meanbp_mean',
#  'resprate_min',
#  'resprate_max',
#  'resprate_mean',
#  'tempc_min',
#  'tempc_max',
#  'tempc_mean',
#  'spo2_min',
#  'spo2_max',
#  'spo2_mean',
#  'glucose_min_y',
#  'glucose_max_y',
#  'glucose_mean']

# %%
## 找出包含 hadm_id 字元
"""
for s in All.columns:
    if "hadm_id" in s:
        print(s)
"""
matching = [s for s in All.columns if "hadm_id" in s]

# %%
matching
# Out:
# ['hadm_id_x', 'hadm_id_y', 'hadm_id_x', 'hadm_id_y', 'hadm_id_x', 'hadm_id_y']

# %%
## 一次分別篩選包含不同的字元
"""
for s in All.columns:
    if "hadm_id" in s or "subject_id" in s:
        print(s)
"""
matching = [s for s in All.columns if "hadm_id" in s or "subject_id" in s]

# %%
matching
# Out:
# ['subject_id_x',
#  'hadm_id_x',
#  'subject_id_y',
#  'hadm_id_y',
#  'subject_id_x',
#  'hadm_id_x',
#  'subject_id_y',
#  'hadm_id_y',
#  'subject_id_x',
#  'hadm_id_x',
#  'subject_id_y',
#  'hadm_id_y']

# %%
## drop 刪除欄位 pd.drop(list,axis=1)

All_f = All.drop(matching,axis=1)

# %%
list(All_f.columns)
# Out:
# ['icustay_id',
#  'los',
#  'intime',
#  'outtime',
#  'first_careunit',
#  'admittime',
#  'deathtime',
#  'dischtime',
#  'dob',
#  'dod',
#  'gender',
#  'age',
#  'mortality_90d',
#  'mingcs',
#  'gcsmotor',
#  'gcsverbal',
#  'gcseyes',
#  'endotrachflag',
#  'aniongap_min',
#  'aniongap_max',
#  'albumin_min',
#  'albumin_max',
#  'bands_min',
#  'bands_max',
#  'bicarbonate_min',
#  'bicarbonate_max',
#  'bilirubin_min',
#  'bilirubin_max',
#  'creatinine_min',
#  'creatinine_max',
#  'chloride_min',
#  'chloride_max',
#  'glucose_min_x',
#  'glucose_max_x',
#  'hematocrit_min',
#  'hematocrit_max',
#  'hemoglobin_min',
#  'hemoglobin_max',
#  'lactate_min',
#  'lactate_max',
#  'platelet_min',
#  'platelet_max',
#  'potassium_min',
#  'potassium_max',
#  'ptt_min',
#  'ptt_max',
#  'inr_min',
#  'inr_max',
#  'pt_min',
#  'pt_max',
#  'sodium_min',
#  'sodium_max',
#  'bun_min',
#  'bun_max',
#  'wbc_min',
#  'wbc_max',
#  'sapsii',
#  'sapsii_prob',
#  'age_score',
#  'hr_score',
#  'sysbp_score',
#  'temp_score',
#  'pao2fio2_score',
#  'uo_score',
#  'bun_score',
#  'wbc_score',
#  'potassium_score',
#  'sodium_score',
#  'bicarbonate_score',
#  'bilirubin_score',
#  'gcs_score',
#  'comorbidity_score',
#  'admissiontype_score',
#  'urineoutput',
#  'heartrate_min',
#  'heartrate_max',
#  'heartrate_mean',
#  'sysbp_min',
#  'sysbp_max',
#  'sysbp_mean',
#  'diasbp_min',
#  'diasbp_max',
#  'diasbp_mean',
#  'meanbp_min',
#  'meanbp_max',
#  'meanbp_mean',
#  'resprate_min',
#  'resprate_max',
#  'resprate_mean',
#  'tempc_min',
#  'tempc_max',
#  'tempc_mean',
#  'spo2_min',
#  'spo2_max',
#  'spo2_mean',
#  'glucose_min_y',
#  'glucose_max_y',
#  'glucose_mean']

# %%
All_f.describe()
# Out:
#           icustay_id           los           age  mortality_90d        mingcs  \
# count   14811.000000  14811.000000  14811.000000   14811.000000  14786.000000
# mean   250054.566943      7.269390     65.009520       0.316859     13.509807
# std     28714.402675      9.077396     15.497262       0.465268      2.829444
# min    200003.000000      0.089200     19.000000       0.000000      3.000000
# 25%    225285.500000      1.956400     55.000000       0.000000     14.000000
# 50%    250404.000000      3.969900     67.000000       0.000000     15.000000
# 75%    275026.500000      8.991550     78.000000       1.000000     15.000000
# max    299998.000000    173.072500     89.000000       1.000000     15.000000
#
#            gcsmotor     gcsverbal       gcseyes  endotrachflag  aniongap_min  \
# count  14609.000000  14684.000000  14730.000000   14786.000000  14486.000000
# mean       4.925594      2.707913      2.923354       0.312728     13.461963
# std        1.730472      2.219425      1.188936       0.463620      3.691621
# min        1.000000      0.000000      1.000000       0.000000      1.000000
# 25%        5.000000      0.000000      2.000000       0.000000     11.000000
# 50%        6.000000      4.000000      3.000000       0.000000     13.000000
# 75%        6.000000      5.000000      4.000000       1.000000     15.000000
# max        6.000000      5.000000      4.000000       1.000000     47.000000
#
#        ...  resprate_mean     tempc_min     tempc_max    tempc_mean  \
# count  ...   14800.000000  14615.000000  14615.000000  14615.000000
# mean   ...      19.977608     36.103287     37.604615     36.874100
# std    ...       4.436917      0.884628      0.905112      0.729666
# min    ...       7.000000     15.000000     32.200000     31.955555
# 25%    ...      16.818182     35.611111     36.999999     36.402778
# 50%    ...      19.416667     36.166666     37.500000     36.841270
# 75%    ...      22.571429     36.611112     38.166667     37.333333
# max    ...      42.500000     39.722222     42.777778     40.103922
#
#            spo2_min      spo2_max     spo2_mean  glucose_min_y  glucose_max_y  \
# count  14795.000000  14795.000000  14795.000000   14690.000000   14690.000000
# mean      90.512538     99.570909     96.968389     108.522422     256.557318
# std        9.527865      1.370228      3.004000      36.576725    8249.633719
# min        2.000000     27.000000     11.166667       0.830000      21.000000
# 25%       90.000000    100.000000     95.920000      86.000000     130.000000
# 50%       93.000000    100.000000     97.440000     104.000000     164.000000
# 75%       95.000000    100.000000     98.708333     126.000000     218.000000
# max      100.000000    100.000000    100.000000     480.000000  999999.000000
#
#         glucose_mean
# count   14690.000000
# mean      152.832665
# std      1179.352291
# min        21.000000
# 25%       111.333333
# 50%       133.115556
# 75%       163.000000
# max    142966.857143
#
# [8 rows x 89 columns]

# %% [markdown]
# # 數據呈現
# * count 數據總量
# * mean 數據平均
# * std 數據標準差
# * 25%, 50%, 75% 數據四分位
# * max 數據最大值

# %%
All_f.head()
# Out:
#    icustay_id      los                   intime                  outtime  \
# 0      298201   9.8318  2185-09-04 21:48:19.000  2185-09-14 17:46:08.000
# 1      204941   3.8644  2141-09-10 23:14:32.000  2141-09-14 19:59:19.000
# 2      256303   1.3024  2157-01-06 10:36:14.000  2157-01-07 17:51:42.000
# 3      222141   1.0441  2157-01-12 16:59:09.000  2157-01-13 18:02:43.000
# 4      266076  13.8661  2157-01-19 18:53:02.000  2157-02-02 15:40:15.000
#
#   first_careunit                admittime                deathtime  \
# 0           MICU  2185-09-01 03:19:00.000  2185-09-14 15:30:00.000
# 1           MICU  2141-09-10 23:13:00.000                     None
# 2            CCU  2157-01-06 10:35:00.000                     None
# 3            CCU  2157-01-06 10:35:00.000                     None
# 4           MICU  2157-01-06 10:35:00.000                     None
#
#                  dischtime                      dob                      dod  \
# 0  2185-09-14 15:30:00.000  2127-12-23 00:00:00.000  2185-09-14 00:00:00.000
# 1  2141-10-05 15:15:00.000  2063-12-13 00:00:00.000  2141-12-11 00:00:00.000
# 2  2157-02-08 15:30:00.000  2099-11-05 00:00:00.000  2157-10-18 00:00:00.000
# 3  2157-02-08 15:30:00.000  2099-11-05 00:00:00.000  2157-10-18 00:00:00.000
# 4  2157-02-08 15:30:00.000  2099-11-05 00:00:00.000  2157-10-18 00:00:00.000
#
#    ... resprate_mean  tempc_min  tempc_max  tempc_mean  spo2_min  spo2_max  \
# 0  ...     17.718750  37.222222  38.333333   37.563492      97.0     100.0
# 1  ...     18.033333  36.111111  38.166665   37.063492      98.0     100.0
# 2  ...     18.000000  36.111111  36.833335   36.564815      94.0     100.0
# 3  ...     21.400000  36.222221  37.111113   36.666667      90.0     100.0
# 4  ...     30.156627  36.000002  37.277777   36.736112      62.0     100.0
#
#    spo2_mean  glucose_min_y  glucose_max_y  glucose_mean
# 0  99.384615           87.0          103.0     92.333333
# 1  99.807692           74.0          108.0     88.200000
# 2  98.909091           97.0          135.0    115.000000
# 3  98.260870           87.0          205.0    129.250000
# 4  97.486486           59.0          123.0     79.500000
#
# [5 rows x 98 columns]

# %%
## 計算各欄位的筆數
All_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14811 entries, 0 to 14810
# Data columns (total 98 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   icustay_id           14811 non-null  int64
#  1   los                  14811 non-null  float64
#  2   intime               14811 non-null  object
#  3   outtime              14811 non-null  object
#  4   first_careunit       14811 non-null  object
#  5   admittime            14811 non-null  object
#  6   deathtime            3139 non-null   object
#  7   dischtime            14811 non-null  object
#  8   dob                  14811 non-null  object
#  9   dod                  8626 non-null   object
#  10  gender               14811 non-null  object
#  11  age                  14811 non-null  int64
#  12  mortality_90d        14811 non-null  int64
#  13  mingcs               14786 non-null  float64
#  14  gcsmotor             14609 non-null  float64
#  15  gcsverbal            14684 non-null  float64
#  16  gcseyes              14730 non-null  float64
#  17  endotrachflag        14786 non-null  float64
#  18  aniongap_min         14486 non-null  float64
#  19  aniongap_max         14486 non-null  float64
#  20  albumin_min          5585 non-null   float64
#  21  albumin_max          5585 non-null   float64
#  22  bands_min            2052 non-null   float64
#  23  bands_max            2052 non-null   float64
#  24  bicarbonate_min      14554 non-null  float64
#  25  bicarbonate_max      14554 non-null  float64
#  26  bilirubin_min        7265 non-null   float64
#  27  bilirubin_max        7265 non-null   float64
#  28  creatinine_min       14568 non-null  float64
#  29  creatinine_max       14568 non-null  float64
#  30  chloride_min         14585 non-null  float64
#  31  chloride_max         14585 non-null  float64
#  32  glucose_min_x        14581 non-null  float64
#  33  glucose_max_x        14581 non-null  float64
#  34  hematocrit_min       14523 non-null  float64
#  35  hematocrit_max       14523 non-null  float64
#  36  hemoglobin_min       14452 non-null  float64
#  37  hemoglobin_max       14452 non-null  float64
#  38  lactate_min          8800 non-null   float64
#  39  lactate_max          8800 non-null   float64
#  40  platelet_min         14447 non-null  float64
#  41  platelet_max         14447 non-null  float64
#  42  potassium_min        14623 non-null  float64
#  43  potassium_max        14623 non-null  float64
#  44  ptt_min              12067 non-null  float64
#  45  ptt_max              12067 non-null  float64
#  46  inr_min              12162 non-null  float64
#  47  inr_max              12162 non-null  float64
#  48  pt_min               12163 non-null  float64
#  49  pt_max               12163 non-null  float64
#  50  sodium_min           14596 non-null  float64
#  51  sodium_max           14596 non-null  float64
#  52  bun_min              14567 non-null  float64
#  53  bun_max              14567 non-null  float64
#  54  wbc_min              14442 non-null  float64
#  55  wbc_max              14442 non-null  float64
#  56  sapsii               14811 non-null  int64
#  57  sapsii_prob          14811 non-null  float64
#  58  age_score            14811 non-null  int64
#  59  hr_score             14811 non-null  float64
#  60  sysbp_score          14802 non-null  float64
#  61  temp_score           14615 non-null  float64
#  62  pao2fio2_score       7859 non-null   float64
#  63  uo_score             14779 non-null  float64
#  64  bun_score            14762 non-null  float64
#  65  wbc_score            14732 non-null  float64
#  66  potassium_score      14776 non-null  float64
#  67  sodium_score         14774 non-null  float64
#  68  bicarbonate_score    14749 non-null  float64
#  69  bilirubin_score      9176 non-null   float64
#  70  gcs_score            14786 non-null  float64
#  71  comorbidity_score    14811 non-null  int64
#  72  admissiontype_score  14811 non-null  int64
#  73  urineoutput          14779 non-null  float64
#  74  heartrate_min        14811 non-null  float64
#  75  heartrate_max        14811 non-null  float64
#  76  heartrate_mean       14811 non-null  float64
#  77  sysbp_min            14802 non-null  float64
#  78  sysbp_max            14802 non-null  float64
#  79  sysbp_mean           14802 non-null  float64
#  80  diasbp_min           14801 non-null  float64
#  81  diasbp_max           14801 non-null  float64
#  82  diasbp_mean          14801 non-null  float64
#  83  meanbp_min           14811 non-null  float64
#  84  meanbp_max           14811 non-null  float64
#  85  meanbp_mean          14811 non-null  float64
#  86  resprate_min         14800 non-null  float64
#  87  resprate_max         14800 non-null  float64
#  88  resprate_mean        14800 non-null  float64
#  89  tempc_min            14615 non-null  float64
#  90  tempc_max            14615 non-null  float64
#  91  tempc_mean           14615 non-null  float64
#  92  spo2_min             14795 non-null  float64
#  93  spo2_max             14795 non-null  float64
#  94  spo2_mean            14795 non-null  float64
#  95  glucose_min_y        14690 non-null  float64
#  96  glucose_max_y        14690 non-null  float64
#  97  glucose_mean         14690 non-null  float64
# dtypes: float64(82), int64(7), object(9)
# memory usage: 11.8+ MB

# %%
## 只取float64和int64的資料
All_num = All_f.select_dtypes(include=['float64',"int64"])

All_num.head()
# Out:
#    icustay_id      los  age  mortality_90d  mingcs  gcsmotor  gcsverbal  \
# 0      298201   9.8318   58              1    15.0       6.0        0.0
# 1      204941   3.8644   78              0    15.0       4.0        0.0
# 2      256303   1.3024   58              0    13.0       6.0        4.0
# 3      222141   1.0441   58              0    15.0       6.0        5.0
# 4      266076  13.8661   58              0    15.0       6.0        5.0
#
#    gcseyes  endotrachflag  aniongap_min  ...  resprate_mean  tempc_min  \
# 0      3.0            1.0          17.0  ...      17.718750  37.222222
# 1      1.0            1.0          13.0  ...      18.033333  36.111111
# 2      3.0            0.0          16.0  ...      18.000000  36.111111
# 3      4.0            0.0          12.0  ...      21.400000  36.222221
# 4      4.0            0.0          13.0  ...      30.156627  36.000002
#
#    tempc_max  tempc_mean  spo2_min  spo2_max  spo2_mean  glucose_min_y  \
# 0  38.333333   37.563492      97.0     100.0  99.384615           87.0
# 1  38.166665   37.063492      98.0     100.0  99.807692           74.0
# 2  36.833335   36.564815      94.0     100.0  98.909091           97.0
# 3  37.111113   36.666667      90.0     100.0  98.260870           87.0
# 4  37.277777   36.736112      62.0     100.0  97.486486           59.0
#
#    glucose_max_y  glucose_mean
# 0          103.0     92.333333
# 1          108.0     88.200000
# 2          135.0    115.000000
# 3          205.0    129.250000
# 4          123.0     79.500000
#
# [5 rows x 89 columns]

# %%
fig = plt.figure(figsize=(5,5))
sns.boxplot(y="age", data=All_num)
plt.boxplot(All_num.age)
plt.show()

# %%
fig = plt.figure(figsize=(30,24))

count = 0
for variable in All_num.columns[:24]:
    count += 1
    
    ## 分割幾張圖
    plt.subplot(4, 6, count)
    
    ## 畫圖，y 為欄位的名稱，data 為資料
    ax = sns.boxplot(y=variable, data=All_num)

plt.show()

# %%
fig = plt.figure(figsize=(30,24))
count = 0
for variable in All_num.columns[:24]:
    count += 1
    plt.subplot(4, 6, count)
    
    ax = sns.boxplot(x = 'mortality_90d', y=variable, data=All_num)
    ax = sns.stripplot(x = 'mortality_90d', y=variable, data=All_num, color="orange", size=5)

plt.show()

# %% [markdown]
# ## 操作：
# 1. 以性別為分組 (設定：All.gender)
# 2. 顯示前六張欄位 (All_num數據)
# 3. 以2,3 或 3,2 顯示圖片
# 4. 點的顏色設定為 yellow

# %%
# 答案
fig = plt.figure(figsize=(30,24))
count = 0
for variable in All_num.columns[:6]:
    count += 1
    plt.subplot(2, 3, count)
    
    ax = sns.boxplot(x = All.gender, y=variable, data=All_num)
    ax = sns.stripplot(x = All.gender, y=variable, data=All_num, color="yellow", size=0.5)

plt.show()

# %%
fig = plt.figure(figsize=(10,10))
sns.scatterplot(data=All_num, x="age", y=All_num.columns[9])
fig.show()

# %%
fig = plt.figure(figsize=(10,10))

sns.scatterplot(data=All_num, x=All_num.columns[10], y=All_num.columns[9],hue ='mortality_90d')
plt.plot(range(41),np.repeat(35,41),'r')
plt.plot(np.repeat(40,36),range(36),'r')

fig.show()

# %%
## pie chart
## count
## autopct 第一位數：位置，小數點後：四捨五入，%：是否要顯示百分位
size = [len(All_num[All_num.age<=30]) , len(All_num[((All_num.age > 30) | (All_num.age <=50))])
        ,len(All_num[All_num.age>50])]
label = ["age<=30", "50<=age<30", "age>50"]
plt.pie(size , labels = label, autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0317cd9a60>,
#   <matplotlib.patches.Wedge at 0x7f0317f362e0>,
#   <matplotlib.patches.Wedge at 0x7f0317f36b80>],
#  [Text(1.0985708093195476, 0.05605512386030496, 'age<=30'),
#   Text(-0.24861536169620832, 1.0715364678482313, '50<=age<30'),
#   Text(0.19368782009986038, -1.082813478095357, 'age>50')],
#  [Text(0.5992204414470259, 0.03057552210562088, '2%'),
#   Text(-0.1356083791070227, 0.5844744370081262, '54%'),
#   Text(0.1056479018726511, -0.5906255335065583, '44%')])

# %% [markdown]
# ## 操作：以圓餅圖顯示mortality 有無的比例 (All_num.mortality_90d)

# %%
size = [len(All_num[All_num.mortality_90d==0]) , len(All_num[All_num.mortality_90d==1])]
label = ['non-Mortality','Mortality']
plt.pie(size , labels = label, autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f03182a93d0>,
#   <matplotlib.patches.Wedge at 0x7f03182a94f0>],
#  [Text(-0.5985452087514628, 0.9228995790879244, 'non-Mortality'),
#   Text(0.5985452951595547, -0.9228995230480735, 'Mortality')],
#  [Text(-0.32647920477352516, 0.5033997704115951, '68%'),
#   Text(0.3264792519052116, -0.5033997398444037, '32%')])

# %%
## Histogram
## 不區分類別
#  All_num.columns[9]
sns.histplot(All_num[All_num.columns[9]] , color="skyblue", label=All_num.columns[9])
sns.histplot(All_num[All_num.columns[10]] , color="red", label=All_num.columns[10])
plt.xlabel("Value")
#plt.ylabel("")
plt.legend()

# %%
## Histogram
## 是否死亡
sns.histplot( All_num[All_num.columns[9]][All_num.mortality_90d==0] , color="skyblue", label=[All_num.columns[9]+"+dead"])
sns.histplot( All_num[All_num.columns[9]][All_num.mortality_90d==1] , color="red", label=[All_num.columns[9]+"+live"])
plt.xlabel("Value")
#plt.ylabel("")
plt.legend(loc='best', bbox_to_anchor=(1, 1))

# %%
## Histogram
## 分類別
fig = plt.figure(figsize=(5,5))
sns.histplot(data = All_num , x = All_num.columns[9], hue ='mortality_90d', element="step")
plt.xlabel("Value")
#plt.ylabel("")
fig.show()

# %% [markdown]
# ## 3. 視覺化呈現資料以時間排列

# %% [markdown]
# # 視覺化各種時段數據偵測，或者藥物使用劑量
# ## 1. 整合chartevents、D_items、icustay
# ## 2. 參考網址 [https://github.com/MIT-LCP/mimic-iii-paper]

# %%
import time
t1 = time.time()
# !/root/anaconda3/bin/pip install psycopg2-binary

## 連線postgresql的套件
import psycopg2
## 建立資料結構的套件，使用於資料處理，如：分割、合併等等 (Python data analysis)
import pandas as pd

## 設定連接資料庫參數
conn = psycopg2.connect(database="mimic", user="twmimicviewer", 
                        password="twmimicviewer@1234", host="203.145.218.182", port="5432")

## 連接上資料庫，抓取資料。

## 允許python執行postgresql語法
with conn.cursor() as cur:

    ## 觀察查詢筆數
    print(cur.rowcount)
    
    ## SQL語法
    sql = """
    SELECT ce.icustay_id
      , ce.charttime
      , ce.charttime - ie.intime AS icutime
      , di.label
      , ce.value
      , ce.valuenum
      , ce.valueuom
    FROM mimiciii.chartevents ce
    INNER join mimiciii.d_items di
    ON ce.itemid = di.itemid
    INNER join mimiciii.icustays ie
    ON ce.icustay_id = ie.icustay_id
    WHERE ce.icustay_id = 276024
    AND error != 1
    ORDER BY ce.charttime
    """
    
    ## 執行sql語法
    cur.execute(sql)
    
    ## 取得欄位名稱
    name = [desc[0] for desc in cur.description]
    
    ## fetchall是將所有收尋的資料都寫入 rows 中
    # rows = pd.DataFrame(cur.fetchall())
    rows = pd.DataFrame(cur.fetchall(),columns=name)
    
t2 = time.time()
print('time elapsed: ' + str(round(t2-t1, 2)) + ' seconds')
# Out:
# -1
# time elapsed: 13.58 seconds

# %%
rows.shape
# Out:
# (9487, 7)

# %%
rows.head()
# Out:
#    icustay_id           charttime           icutime  \
# 0      276024 2133-01-24 17:00:00 -1 days +23:31:53
# 1      276024 2133-01-24 17:00:00 -1 days +23:31:53
# 2      276024 2133-01-24 17:00:00 -1 days +23:31:53
# 3      276024 2133-01-24 17:28:00 -1 days +23:59:53
# 4      276024 2133-01-24 17:28:00 -1 days +23:59:53
#
#                                label           value  valuenum valueuom
# 0       Arterial Blood Pressure mean              83      83.0     mmHg
# 1   Arterial Blood Pressure systolic             115     115.0     mmHg
# 2  Arterial Blood Pressure diastolic              64      64.0     mmHg
# 3                           Religion  Roman Catholic      13.0     None
# 4                   Patient Location            CC5B       NaN     None

# %%
## dt.days，顯示天數
## dt.seconds，計算小於1天數據，以秒數顯示
# rows.icutime.dt.days
print(rows['icutime'][0])
print(rows['icutime'].dt.seconds[0])
print(23*60*60+31*60+53)
print(rows['icutime'].dt.days[0])
# Out:
# -1 days +23:31:53
# 84713
# 84713
# -1

# %%
# 去除超過某個時間後的資料
maxdays = 5;
rows = rows.loc[rows.icutime.dt.days<=maxdays]

# %%
rows.shape
# Out:
# (9407, 7)

# %%
# 將時間資料轉換成以天為單位
rows['icutimehr'] = (rows['icutime'].dt.seconds/60/60)+(rows['icutime'].dt.days*24)

# %%
# 不能用list
dict(rows['label'].value_counts())
# Out:
# {'Heart Rate': 167,
#  'Arterial Blood Pressure mean': 165,
#  'Arterial Blood Pressure diastolic': 164,
#  'Arterial Blood Pressure systolic': 164,
#  'O2 saturation pulseoxymetry': 162,
#  'Respiratory Rate': 161,
#  'Heart Rhythm': 144,
#  'Central Venous Pressure': 134,
#  'Safety Measures_U_1': 111,
#  'Temperature Site': 95,
#  'Temperature Fahrenheit': 94,
#  'Impaired Skin Site #4': 91,
#  'CO (Arterial)': 84,
#  'SVV (Arterial)': 75,
#  'Ectopy Type 1': 74,
#  'Head of Bed': 53,
#  'Assistance Device': 53,
#  'Activity Tolerance': 52,
#  'Position': 52,
#  'Activity': 52,
#  'Turn': 50,
#  'Therapeutic Bed': 48,
#  'Anti Embolic Device': 48,
#  'Anti Embolic Device Status': 48,
#  'Pressure Reducing Device': 45,
#  'PEEP set': 43,
#  'Inspired O2 Fraction': 43,
#  'PH (Arterial)': 42,
#  'Pain Assessment Method': 42,
#  'Respiratory Rate (Set)': 42,
#  'Pain Present': 41,
#  'Arterial O2 pressure': 41,
#  'TCO2 (calc) Arterial': 41,
#  'Arterial Base Excess': 41,
#  'Tidal Volume (set)': 41,
#  'Arterial CO2 Pressure': 41,
#  'Mean Airway Pressure': 40,
#  'SV (Arterial)': 40,
#  'Tidal Volume (observed)': 40,
#  'Daily Wake Up Deferred': 40,
#  'Peak Insp. Pressure': 40,
#  'Minute Volume': 40,
#  'Ventilator Mode': 40,
#  'Impaired Skin Treatment #2': 40,
#  'Inspiratory Time': 40,
#  'RUL Lung Sounds': 39,
#  'LUL Lung Sounds': 39,
#  'Ventilator Type': 39,
#  'Respiratory Rate (Total)': 39,
#  'Expiratory Ratio': 39,
#  'RLL Lung Sounds': 39,
#  'LLL Lung Sounds': 39,
#  'Inspiratory Ratio': 39,
#  'Minute Volume Alarm - Low': 38,
#  'Paw High': 38,
#  'Lactic Acid': 38,
#  'Apnea Interval': 38,
#  'Minute Volume Alarm - High': 38,
#  'Flow Pattern': 37,
#  'Inspired Gas Temp.': 37,
#  'Flow Sensitivity': 37,
#  'Humidification': 37,
#  'Flow Rate (variable/fixed)': 37,
#  'Pain Management': 37,
#  'Ionized Calcium': 36,
#  'Side Rails': 35,
#  'Oral Care': 35,
#  'Alarms On': 35,
#  'Warming Device': 34,
#  'Pain Level Acceptable': 34,
#  'Parameters Checked': 34,
#  'Fspn High': 34,
#  'Pupil Response Right': 33,
#  'Pupil Response Left': 33,
#  'Pupil Size Left': 33,
#  'Pupil Size Right': 33,
#  'Incision Appearance #1': 32,
#  'LL Strength/Movement': 31,
#  'RL Strength/Movement': 31,
#  'RU Strength/Movement': 31,
#  'Respiratory Pattern': 31,
#  'Pain Level': 31,
#  'Abdominal Assessment': 31,
#  'LU Strength/Movement': 31,
#  'Level of Consciousness': 31,
#  'GCS - Motor Response': 30,
#  'GCS - Eye Opening': 30,
#  'GCS - Verbal Response': 30,
#  'Replacement Rate': 30,
#  'ETT Size (ID)': 30,
#  'ETT Type': 30,
#  'Response': 30,
#  'ETT Mark (cm)': 30,
#  'ETT Location': 30,
#  'PBP (Prefilter) Replacement Rate': 30,
#  'Dialysate Rate': 30,
#  'System Integrity': 30,
#  'Spontaneous Movement': 30,
#  'Response to Stimuli (Type)': 29,
#  'Cough Effort': 29,
#  'Respiratory Effort': 29,
#  'Current Goal': 29,
#  'Respiratory Rate (spontaneous)': 29,
#  'Replacement Fluid': 29,
#  'Speech': 29,
#  'Orientation': 29,
#  'Dorsal PedPulse L': 29,
#  'Dialysate Fluid': 29,
#  'Plateau Pressure': 29,
#  'Dorsal PedPulse R': 29,
#  'Ultrafiltrate Output': 28,
#  'Oral Cavity': 28,
#  'Daily Wake Up': 28,
#  'GI #1 Tube Status': 28,
#  'Gag Reflex': 28,
#  'GI #1 Tube Type': 28,
#  'Nares L': 28,
#  'GI #1 Intub Site': 28,
#  'Diet Type': 28,
#  'Cough Reflex': 28,
#  'Nares R': 28,
#  'Education Topic': 28,
#  'Vti High': 27,
#  'O2 Delivery Device(s)': 27,
#  'Slope': 26,
#  'Urine Source': 26,
#  'Impaired Skin Treatment #1': 26,
#  'Impaired Skin Treatment #4': 26,
#  'Hourly Patient Fluid Removal': 26,
#  'Post Filter Replacement Rate': 26,
#  'Skin Care': 26,
#  'Blood Flow (ml/min)': 26,
#  'Filter Pressure': 25,
#  'Access Pressure': 25,
#  'Bowel Sounds': 25,
#  'Effluent Pressure': 25,
#  'Support Systems': 25,
#  'GI #1 Tube Drainage': 25,
#  'Return Pressure': 25,
#  'Subglottal Suctioning': 24,
#  'Edema Location': 24,
#  'Warming Device Status': 24,
#  'CRRT mode': 23,
#  'Untoward Effect': 23,
#  'Riker-SAS Scale': 23,
#  'Sodium (serum)': 23,
#  'Glucose (serum)': 23,
#  'BUN': 22,
#  'Arterial Line Dressing Occlusive': 22,
#  'GI #1 Tube Place Check': 22,
#  'Arterial line Site Appear': 22,
#  'HCO3 (serum)': 22,
#  'Incision Site #1': 22,
#  'Arterial Line placed in outside facility': 22,
#  'Dressing Status #1': 22,
#  'Chloride (serum)': 22,
#  'Potassium (serum)': 22,
#  'Incision Closure #1': 22,
#  'Eye Care': 22,
#  'Magnesium': 22,
#  'Arterial line Waveform Appear': 22,
#  'Incision Drainage #1': 22,
#  'Braden Sensory Perception': 21,
#  'Creatinine': 21,
#  'Hemoglobin': 21,
#  'Incision Packing #1': 21,
#  'Incision Dressing #1': 21,
#  'Skin Temperature': 21,
#  'Platelet Count': 21,
#  'Braden Mobility': 21,
#  'Anion gap': 21,
#  'Braden Friction/Shear': 21,
#  'Braden Activity': 21,
#  'WBC': 21,
#  'Ectopy Frequency 1': 21,
#  'Incision Drainage Amount #1': 21,
#  'Hematocrit (serum)': 21,
#  'Incision Cleansing #1': 21,
#  'Braden Nutrition': 21,
#  'Braden Moisture': 21,
#  'Phosphorous': 21,
#  'Surrounding Tissue #1': 21,
#  'Skin Integrity': 21,
#  'Urine Color': 20,
#  'Corneal Reflex Right': 20,
#  'Calcium non-ionized': 20,
#  'Skin Condition': 20,
#  'Prothrombin time': 20,
#  'Impaired Skin Site #2': 20,
#  'PostTib. Pulses L': 20,
#  'Multi Lumen Dressing Occlusive': 20,
#  'Impaired Skin Drainage #2': 20,
#  'Skin Color': 20,
#  'Multi Lumen placed in outside facility': 20,
#  'Glucose (whole blood)': 20,
#  'Surrounding Tissue #2': 20,
#  'Multi Lumen Site Appear': 20,
#  'PostTib. Pulses R': 20,
#  'Impaired Skin Type #2': 20,
#  'PTT': 20,
#  'INR': 20,
#  'Pressure Ulcer Stage #2': 20,
#  'Impaired Skin Drainage #1': 19,
#  'Impaired Skin Site #1': 19,
#  'Pain Level Response': 19,
#  'Impaired Skin Odor #1': 19,
#  'Impaired Skin Type #1': 19,
#  'Pressure Ulcer Stage #1': 19,
#  'Edema Amount': 19,
#  'Corneal Reflex Left': 19,
#  'Impaired Skin Wound Base #1': 19,
#  'Back Care': 18,
#  'Impaired Skin Drainage #3': 18,
#  'Impaired Skin Wound Base #3': 18,
#  'Pressure Ulcer Stage #3': 18,
#  'GI #3 Tube Type': 18,
#  'GI #3 Tube Status': 18,
#  'GI #1 Tube Place Method': 18,
#  'Mental status': 18,
#  'Pain Location': 18,
#  'Gait/Transferring': 18,
#  'Multi Lumen Waveform Appear': 18,
#  'Ambulatory aid': 18,
#  'GI #2 Tube Type': 18,
#  'History of falling (within 3 mnths)': 18,
#  'Impaired Skin Site #3': 18,
#  'Surrounding Tissue #3': 18,
#  'Secondary diagnosis': 18,
#  'GI #2 Tube Status': 18,
#  'Impaired Skin Type #3': 18,
#  'Impaired Skin Treatment #3': 18,
#  'Cough Type': 18,
#  'GI #2 Tube Drainage': 18,
#  'IV/Saline lock': 18,
#  'Sputum Source': 17,
#  'Incision Appearance #2': 17,
#  'ART BP mean': 17,
#  'ART BP Diastolic': 17,
#  'Incision Closure #2': 17,
#  'Incision Site #2': 17,
#  'ART BP Systolic': 17,
#  'Sputum Amount': 17,
#  'GI #3 Intub Site': 17,
#  'Dressing Status #2': 17,
#  'GI #2 Intub Site': 17,
#  'Impaired Skin Drainage Amount #1': 16,
#  'Incision Dressing #2': 16,
#  'Incision Drainage #2': 16,
#  'LUE Temp': 16,
#  'Incision Drainage Amount #2': 16,
#  'RLE Temp': 16,
#  'RUE Color': 16,
#  'Urine Appearance': 16,
#  'RUE Temp': 16,
#  'LLE Color': 16,
#  'RLE Color': 16,
#  'LUE Color': 16,
#  'LLE Temp': 16,
#  'Education Barrier': 15,
#  'Richmond-RAS Scale': 15,
#  'Family Communication': 15,
#  'Multi Lumen Placement Confirmed by X-ray': 15,
#  'Capillary Refill R': 14,
#  'Glucose finger stick': 14,
#  'Heart Rate Alarm - Low': 14,
#  'Capillary Refill L': 14,
#  'Ventilator Tank #1': 14,
#  'Fibrinogen': 14,
#  'Heart rate Alarm - High': 14,
#  'Education Response': 13,
#  'Surrounding Tissue #4': 13,
#  'Education Learner': 13,
#  'Education Readiness': 13,
#  'Impaired Skin - Dressing Status  #4': 13,
#  'Impaired Skin Drainage #4': 13,
#  'Education Method': 13,
#  'Impaired Skin Cleanse #4': 13,
#  'Ventilator Tank #2': 13,
#  'Arterial Line Zero/Calibrate': 13,
#  'Impaired Skin Drainage Amount #4': 13,
#  'Impaired Skin Type #4': 13,
#  'Sputum Color': 12,
#  'Impaired Skin Cleanse #1': 12,
#  'Impaired Skin  - Dressing Status #1': 12,
#  'AST': 12,
#  'ALT': 12,
#  'Sputum Consistency': 12,
#  'Impaired Skin Length #1': 12,
#  'Impaired Skin Width #1': 12,
#  'O2 Saturation Pulseoxymetry Alarm - Low': 12,
#  'SpO2 Desat Limit': 12,
#  'Cordis/Introducer placed in outside facility': 12,
#  'Total Bilirubin': 12,
#  'O2 Saturation Pulseoxymetry Alarm - High': 12,
#  'Cordis/Introducer Dressing Occlusive': 12,
#  'Cordis/Introducer Site Appear': 12,
#  'Alkaline Phosphate': 12,
#  'Arterial Blood Pressure Alarm - High': 11,
#  'Potassium (whole blood)': 11,
#  'ABP Alarm Source': 11,
#  'Arterial Blood Pressure Alarm - Low': 11,
#  'Citrate (ACD-A)': 11,
#  'Radial Pulse R': 10,
#  'Central Venous Pressure Alarm - High': 10,
#  'GI #2 Tube Place Check': 10,
#  'Cuff Pressure': 10,
#  'Dialysis Catheter placed in outside facility': 10,
#  'Central Venous Pressure  Alarm - Low': 10,
#  'Resp Alarm - Low': 10,
#  'Radial Pulse L': 10,
#  'Resp Alarm - High': 10,
#  'Multi Lumen Zero/Calibrate': 10,
#  'Lipase': 9,
#  'Dialysis Catheter Placement Confirmed by X-ray': 9,
#  'Albumin': 9,
#  'Dialysis Catheter Type': 9,
#  'VEN Lumen Volume': 9,
#  'Dialysis Catheter Site Appear': 9,
#  'Impaired Skin Site #5': 8,
#  'Troponin-T': 8,
#  'CK (CPK)': 8,
#  'Impaired Skin Wound Base #5': 8,
#  'GI #3 Tube Place Check': 7,
#  'Ostomy': 7,
#  'RSBI Deferred': 7,
#  'All Medications Tolerated without Adverse Side Effects': 7,
#  'CK-MB': 7,
#  'Pain Cause': 7,
#  'Chloride (whole blood)': 6,
#  'Pain Type': 6,
#  'GI #2 Tube Place Method': 6,
#  'Sodium (whole blood)': 6,
#  'Amylase': 6,
#  'Religion': 5,
#  'Hematocrit (whole blood - calc)': 5,
#  'Smoking Cessation Info Offered through BIDMC Inpatient Guide': 5,
#  'Intravenous  / IV access prior to admission': 5,
#  'Bed Bath': 5,
#  'Patient Location': 5,
#  'CK-MB fraction (%)': 5,
#  'ETOH': 5,
#  'CV - past medical history': 5,
#  'Tobacco Use History': 5,
#  'Arterial O2 Saturation': 5,
#  'Recreational drug use': 5,
#  'Ostomy Appearance': 5,
#  'Impaired Skin Type #5': 4,
#  'Total PEEP Level': 4,
#  'LDH': 4,
#  'Non Invasive Blood Pressure mean': 3,
#  'Vancomycin (Random)': 3,
#  'Non Invasive Blood Pressure diastolic': 3,
#  'Non Invasive Blood Pressure systolic': 3,
#  'Direct Bilirubin': 3,
#  'Daily Weight': 3,
#  'Differential-Eos': 2,
#  'Differential-Basos': 2,
#  'Differential-Monos': 2,
#  'ART Blood Pressure Alarm - Low': 2,
#  'Pronator drift present': 2,
#  'Bladder Pressure': 2,
#  'ART Blood Pressure Alarm Source': 2,
#  'ART Blood Pressure Alarm - High': 2,
#  'Differential-Atyps': 2,
#  'Differential-Lymphs': 2,
#  'High risk (>51) interventions': 2,
#  'Stool Management': 2,
#  'Admission Weight (lbs.)': 2,
#  'Differential-Neuts': 2,
#  'Differential-Bands': 2,
#  'Service': 1,
#  'Admit from': 1,
#  'Stool Consistency': 1,
#  'Height': 1,
#  'Temperature Celsius': 1,
#  'Code Status': 1,
#  'Heparin Dose (per hour)': 1,
#  'NBP Alarm Source': 1,
#  'Admission Weight (Kg)': 1,
#  'Height (cm)': 1,
#  'Flatus': 1,
#  'Restraint (Non-violent)': 1,
#  'Non-Invasive Blood Pressure Alarm - High': 1,
#  'Non-Invasive Blood Pressure Alarm - Low': 1,
#  'Restraint Location': 1,
#  'Precautions: Standard +': 1,
#  'Stool Color': 1}

# %%
# 得到三種數據的平均值
hr_mean = rows.valuenum[rows.label=='Heart Rate'].mean()
bp_mean = rows.icutimehr[rows.label=='Non Invasive Blood Pressure mean'].mean()
temp_mean = ((rows.valuenum[rows.label=='Temperature Fahrenheit']-32)/1.8).mean()

# 列出平均數值
print("Mean HR is: {0:.2f}".format(hr_mean))
print("Mean BP is: {0:.2f}".format(bp_mean))
print("Mean temp, C is: {0:.2f}".format(temp_mean))
# Out:
# Mean HR is: 100.56
# Mean BP is: 57.90
# Mean temp, C is: 36.38

# %%
# 得到三種數據的平均值
hr_describe = rows.valuenum[rows.label=='Heart Rate'].describe()
bp_describe = rows.icutimehr[rows.label=='Non Invasive Blood Pressure mean'].describe()
temp_describe = ((rows.valuenum[rows.label=='Temperature Fahrenheit']-32)/1.8).describe()

# 列出其餘統計數值
print("Describe HR is:\n",hr_describe,"\n")
print("Describe BP is:\n",bp_describe,"\n")
print("Describe temp is:\n",temp_describe,"\n")
# Out:
# Describe HR is:
#  count    167.000000
# mean     100.556886
# std       14.334475
# min       68.000000
# 25%       93.500000
# 50%      101.000000
# 75%      110.000000
# max      142.000000
# Name: valuenum, dtype: float64
#
# Describe BP is:
#  count     3.000000
# mean     57.898056
# std      16.757643
# min      48.181389
# 25%      48.223056
# 50%      48.264722
# 75%      62.756389
# max      77.248056
# Name: icutimehr, dtype: float64
#
# Describe temp is:
#  count    94.000000
# mean     36.381797
# std       0.798713
# min      34.055556
# 25%      35.847222
# 50%      36.583333
# 75%      36.930556
# max      37.888889
# Name: valuenum, dtype: float64

# %%
#hr_describe[1]
#hr_describe["count"]
dict(hr_describe)['max']
# Out:
# 142.0

# %%
# 設定圖片大小 寬*高
fig = plt.figure(figsize=(22, 20))
## 設定XY軸，字大小
plt.rcParams.update({'font.size': 20})

# 設定RGB顏色 
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120)]  

# 因為設定的RGB值域必須在0-1
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
    

# 設定的周圍線顯示狀況
# 圖片位置：subplot(xyz)位置
ax = plt.subplot(111)
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(True)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(True)    
  

# 畫圖
## plot(x,y,color:顏色, lw:線的寬, ls:點連線的方式, marker:點的形狀, markersize:點的大小, label:在圖示的名稱)

# Marker : https://matplotlib.org/3.3.2/api/markers_api.html#module-matplotlib.markers
plt.plot(rows.icutimehr[rows.label=='Heart Rate'], 
         rows.valuenum[rows.label=='Heart Rate'],
         color=tableau20[0], 
         lw=5, ls=":",
         marker='v', markersize=6, label='Heart rate')

plt.plot(rows.icutimehr[rows.label=='O2 saturation pulseoxymetry'], 
         rows.valuenum[rows.label=='O2 saturation pulseoxymetry'],
         color=tableau20[1], 
         lw=2.5, ls="-",
         marker='o', markersize=6, label='O2 saturation')

plt.plot(rows.icutimehr[rows.label=='Non Invasive Blood Pressure mean'], 
         rows.valuenum[rows.label=='Non Invasive Blood Pressure mean'],
         color=tableau20[2], 
         lw=2.5, ls="-.",
         marker='o', markersize=6, label='NIBP, mean')

plt.plot(rows.icutimehr[rows.label=='Respiratory Rate'], 
         rows.valuenum[rows.label=='Respiratory Rate'],
         color=tableau20[3], 
         lw=2.5, ls="",
         marker='v', markersize=6, label='Respiratory rate')

plt.plot(rows.icutimehr[rows.label=='Respiratory Rate'], 
         rows.valuenum[rows.label=='Respiratory Rate'],
         color=tableau20[3], 
         lw=2.5, ls="",
         marker='v', markersize=6, label='Respiratory rate')

# 圖示設定
plt.legend(loc=1,fontsize=18)

# 貼上各種文字
plt.text(40,150,"Example plot",fontsize=40)
# X軸名稱
plt.xlabel('Time after admission to the intensive care unit, hours', fontsize=22)
# Y軸名稱
plt.ylabel('Measurement, absolute value', fontsize=22)
# y軸數值顯示
plt.yticks(np.arange(0, 160, 10))



# 圖片儲存
fig.savefig('examplepatient.pdf', bbox_inches='tight')

# %% [markdown]
# ## 4. 取出病患死亡時間

# %%
# !/root/anaconda3/bin/pip install psycopg2-binary

## 連線postgresql的套件
import psycopg2
## 建立資料結構的套件，使用於資料處理，如：分割、合併等等 (Python data analysis)
import pandas as pd

## 設定連接資料庫參數
conn = psycopg2.connect(database="mimic", user="twmimicadmin", 
                        password="twmimicadmin@1234", host="203.145.218.182", port="5432")

## 連接上資料庫，抓取資料。

## 允許python執行postgresql語法
with conn.cursor() as cur:
    
    time = pd.DataFrame()
    ## SQL語法
    for n in All.icustay_id:
        sql = """
        SELECT
            icu.icustay_id
            , ma.deathtime-icu.INTIME AS leavetime
        FROM mimiciii.icustays icu
        JOIN mimiciii.admissions ma
        ON icu.HADM_ID = ma.HADM_ID
        WHERE icu.icustay_id = """+ str(n)+""" """
        
        cur.execute(sql)
        ## 取得欄位名稱
        #name = [desc[0] for desc in cur.description]

        ## fetchall是將所有收尋的資料都寫入 rows 中
        out = pd.DataFrame(cur.fetchall())
        time = pd.concat([time,out])
    
time.columns = ["icustay_id","leavetime"]

# %%
time.leavetime = (time.leavetime.dt.seconds/60/60)+(time.leavetime.dt.days*24)

# %%
Output = pd.merge(time,All,on="icustay_id")

# %%
Output.head()
# Out:
#    icustay_id   leavetime  subject_id_x  hadm_id_x      los  \
# 0      298201  233.694722         21274     164354   9.8318
# 1      204941         NaN         21277     127461   3.8644
# 2      256303         NaN         18936     166430   1.3024
# 3      222141         NaN         18936     166430   1.0441
# 4      266076         NaN         18936     166430  13.8661
#
#                     intime                  outtime first_careunit  \
# 0  2185-09-04 21:48:19.000  2185-09-14 17:46:08.000           MICU
# 1  2141-09-10 23:14:32.000  2141-09-14 19:59:19.000           MICU
# 2  2157-01-06 10:36:14.000  2157-01-07 17:51:42.000            CCU
# 3  2157-01-12 16:59:09.000  2157-01-13 18:02:43.000            CCU
# 4  2157-01-19 18:53:02.000  2157-02-02 15:40:15.000           MICU
#
#                  admittime                deathtime  ... resprate_mean  \
# 0  2185-09-01 03:19:00.000  2185-09-14 15:30:00.000  ...     17.718750
# 1  2141-09-10 23:13:00.000                     None  ...     18.033333
# 2  2157-01-06 10:35:00.000                     None  ...     18.000000
# 3  2157-01-06 10:35:00.000                     None  ...     21.400000
# 4  2157-01-06 10:35:00.000                     None  ...     30.156627
#
#    tempc_min  tempc_max tempc_mean  spo2_min  spo2_max  spo2_mean  \
# 0  37.222222  38.333333  37.563492      97.0     100.0  99.384615
# 1  36.111111  38.166665  37.063492      98.0     100.0  99.807692
# 2  36.111111  36.833335  36.564815      94.0     100.0  98.909091
# 3  36.222221  37.111113  36.666667      90.0     100.0  98.260870
# 4  36.000002  37.277777  36.736112      62.0     100.0  97.486486
#
#    glucose_min_y  glucose_max_y  glucose_mean
# 0           87.0          103.0     92.333333
# 1           74.0          108.0     88.200000
# 2           97.0          135.0    115.000000
# 3           87.0          205.0    129.250000
# 4           59.0          123.0     79.500000
#
# [5 rows x 111 columns]

# %%
Output.leavetime[-Output.leavetime.isna()]
# Out:
# 0        233.694722
# 9        835.026944
# 15         4.671111
# 17        37.500556
# 18        -0.033889
#             ...
# 14786    142.853333
# 14801    211.561667
# 14806    151.364722
# 14809    376.632778
# 14810    157.788333
# Name: leavetime, Length: 3139, dtype: float64

# %%
## 一次分別篩選包含不同的字元
matching = [s for s in All.columns if "hadm_id" in s or "subject_id" in s]

Output.drop(matching,axis=1).to_csv("Data.csv")
